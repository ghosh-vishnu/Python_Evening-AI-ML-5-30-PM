# %% [markdown]
# ### Python Programining

# %%
# This is my First Code in Python   --single line comment
print("Hello Developers")
# Out:
# Hello Developers

# %%
value="Hello Developers"  # Declare Variable
value="Welcome to Python Programming"
value1='First Code'

# %%
print(value)  # calling Varaible
print(type(value))
print(value1)
print(type(value1))
# Out:
# Welcome to Python Programming
# <class 'str'>
# First Code
# <class 'str'>

# %%
""" hello All this side vishnu
i am from Bihar """   # Multiline Comment
print("Hello India")
# Out:
# Hello India

# %%
a=10
b=15
c=1.5
d=3+4j
f=10+5j
e=True
print(type(a))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %%
print(d+f)
# Out:
# (13+9j)

# %%
print(a+b)
print(a*b)
# Out:
# 25
# 150

# %%
print(a,b,sep="\n")
# Out:
# 10
# 15

# %%
name="Vishnu"   # Use End Operator
print(name,"",end="Kumar")
# Out:
# Vishnu Kumar

# %%
name2="Kunal"

# %%
print(name,name2,sep="\t")
# Out:
# Vishnu	Kunal

# %%
number1="15"
number2=18
print(int(number1)+number2)
# Out:
# 33

# %%
num=15.8
num2=20
print(num+num2)
# Out:
# 35.8

# %%
a="Python"
print((a+"\n")*5)
# Out:
# Python
# Python
# Python
# Python
# Python

# %%
user1=input("Enter Your 1st Number ")
user2=input("Enter Your 2nd Number ")
output=int(user1)+int(user2)
print(output)
print(type(output))
print(type(user1))
# Out:
# Enter Your 1st Number 10
# Enter Your 2nd Number 20
# 30
# <class 'int'>
# <class 'str'>

# %%
b=10
c=float(b)

# %%
print(c)
d=int(c)
# Out:
# 10.0

# %%
print(d)
# Out:
# 10

# %%
value=4.9
print(type(value))
# Out:
# <class 'float'>

# %%
print(int(float(int(value))))
# Out:
# 4

# %% [markdown]
# ### String

# %%
a="Developer"
print(a.upper())
# Out:
# DEVELOPER

# %%
print(a.lower())
# Out:
# developer

# %%
print(a[::-1].lower())
# Out:
# repoleved

# %%
sen="This is My First Programmmmmmmmmmmmmm"
print(sen[11:23])
# Output:
# "First Program"
# Out:
# First Progra

# %%
A=False

# %%
print(type(A))
print(A)
# Out:
# <class 'bool'>
# False

# %% [markdown]
# ### List
#   > List is a Collection Datatype.
#
#   > This is Ordered.
#
#   > It is Mutable/Changeble Datatype.
#
#   > List Support to conatain Duplicates Items or Element
#
#   > List Support Multiple Datatypes.Its Contain Multiple Datatypes value
#
#   > List Literal is []

# %%
list1=[4,5,5,"Python",4.5,5+3j,True]

# %%
print(list1)
# Out:
# [4, 5, 5, 'Python', 4.5, (5+3j), True]

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
c=tuple(list1)

# %%
print(c)
# Out:
# (4, 5, 5, 'Python', 4.5, (5+3j), True)

# %%
d=set(list1)

# %%
print(d)
# Out:
# {True, 4.5, 4, 5, (5+3j), 'Python'}

# %%
print(list1)
# Out:
# [4, 5, 5, 'Python', 4.5, (5+3j), True]

# %%
string=list1[3]

# %%
print(string)
# Out:
# Python

# %%
list1.append("Developer")

# %%
list1
# Out:
# [4, 5, 5, 'Python', 4.5, (5+3j), True, 'Developer']

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
blank=[]

# %%
blank.append("Python")

# %%
blank
# Out:
# ['Python']

# %%
list2=[]
while True:
  user_input=input("Enter Element")
  if user_input=='a':
    break
  list2.append(user_input)
print(list2)
# Out:
# Enter Element3
# Enter Element
# Enter Element
# Enter Element
# Enter Element
# Enter Element
# Enter Element
# Enter Element3
# Enter Element
# Enter Element
# Enter Element
# Enter Element5
# Enter Element
# Enter Element
# Enter Element
# Enter Element
# Enter Elementa
# ['3', '', '', '', '', '', '', '3', '', '', '', '5', '', '', '', '']

# %%
# 1.KNN Metrics
> Euclidean Distance
Distance=root(x2​−x1​)2+(y2​−y1​)2
​

# %%
# Student A
height=160
weight=55


# New Student
height1=163
weight1=58

# %%
# height Diff
print(height1-height)
# Out:
# 3

# %%
print(weight1-weight)
# Out:
# 3

# %%
9+9=18
root(18)=4.24

# %%
# STUDENT B
height=162
weight=58
# New Student 
height1=163
weight1=58

# %%
# height diff
163-162=1
58-57=1

# %%
root(2)
1.414

# Student C
height=175
weight=75
# new_student
height1=163
weight1=58

# %%
height_diff=12
weight_diff=17
144+289=433
root(433)=20.80

# %%
Studnet  height  weight   Sports            Result
A        160       55      Football          4.24                           
B        163       58      FOOTBAL           1.41
C        175       75      BASKET BALL       20.80
new      163       58       --------
FOOTBALL

# %%
IF K=1
SPORT=FOOTBALL

# %%
import math

# Student A
x1=160
y1=55

# New Student
X2=163
Y2=58

distance=math.sqrt((X2-x1)**2+(Y2-y1)**2)
print("Distance is ",distance)
# Out:
# Distance is  4.242640687119285

# %%
import numpy as np
point1=np.array([160,55])
point2=np.array([163,58])
distance=np.sum(np.abs(point2-point1))

# %%
print(distance)
# Out:
# 6

# %%
features
AGE                    25
SALARY                 5000000

# %%
import pandas as pd

# %%
df=pd.read_csv('knn.csv')

# %%
df
# Out:
#    Age  CGPA  AptitudeScore  CodingScore  Communication  Internships  \
# 0   21   8.5             82           90              8            2
# 1   22   7.1             60           55              6            1
# 2   20   9.0             91           95              9            3
# 3   23   6.8             58           60              5            0
# 4   21   8.2             78           82              8            2
# 5   22   7.5             70           72              7            1
# 6   24   5.9             45           40              4            0
# 7   20   9.3             94           97             10            4
# 8   23   6.5             52           48              5            0
# 9   21   8.0             76           80              7            2
#
#    Projects  Attendance Placed
# 0         5          92    Yes
# 1         2          80     No
# 2         6          96    Yes
# 3         1          75     No
# 4         4          90    Yes
# 5         3          85    Yes
# 6         0          68     No
# 7         8          98    Yes
# 8         2          70     No
# 9         4          89    Yes

# %%
print(df.info())
print(df.describe())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            10 non-null     int64
#  1   CGPA           10 non-null     float64
#  2   AptitudeScore  10 non-null     int64
#  3   CodingScore    10 non-null     int64
#  4   Communication  10 non-null     int64
#  5   Internships    10 non-null     int64
#  6   Projects       10 non-null     int64
#  7   Attendance     10 non-null     int64
#  8   Placed         10 non-null     object
# dtypes: float64(1), int64(7), object(1)
# memory usage: 852.0+ bytes
# None
#              Age       CGPA  AptitudeScore  CodingScore  Communication  \
# count  10.000000  10.000000      10.000000    10.000000      10.000000
# mean   21.700000   7.680000      70.600000    71.900000       6.900000
# std     1.337494   1.111356      16.500505    20.206984       1.911951
# min    20.000000   5.900000      45.000000    40.000000       4.000000
# 25%    21.000000   6.875000      58.500000    56.250000       5.250000
# 50%    21.500000   7.750000      73.000000    76.000000       7.000000
# 75%    22.750000   8.425000      81.000000    88.000000       8.000000
# max    24.000000   9.300000      94.000000    97.000000      10.000000
#
#        Internships   Projects  Attendance
# count    10.000000  10.000000   10.000000
# mean      1.500000   3.500000   84.300000
# std       1.354006   2.415229   10.614979
# min       0.000000   0.000000   68.000000
# 25%       0.250000   2.000000   76.250000
# 50%       1.500000   3.500000   87.000000
# 75%       2.000000   4.750000   91.500000
# max       4.000000   8.000000   98.000000
# (10, 9)

# %%
df.shape
# Out:
# (10, 9)

# %%
print(df.isnull().sum())
# Out:
# Age              0
# CGPA             0
# AptitudeScore    0
# CodingScore      0
# Communication    0
# Internships      0
# Projects         0
# Attendance       0
# Placed           0
# dtype: int64

# %%
df.head()
# Out:
#    Age  CGPA  AptitudeScore  CodingScore  Communication  Internships  \
# 0   21   8.5             82           90              8            2
# 1   22   7.1             60           55              6            1
# 2   20   9.0             91           95              9            3
# 3   23   6.8             58           60              5            0
# 4   21   8.2             78           82              8            2
#
#    Projects  Attendance Placed
# 0         5          92    Yes
# 1         2          80     No
# 2         6          96    Yes
# 3         1          75     No
# 4         4          90    Yes

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
# Yes 1
# NO 0

df['Placed']=le.fit_transform(df['Placed'])

# %%
df.head()
# Out:
#    Age  CGPA  AptitudeScore  CodingScore  Communication  Internships  \
# 0   21   8.5             82           90              8            2
# 1   22   7.1             60           55              6            1
# 2   20   9.0             91           95              9            3
# 3   23   6.8             58           60              5            0
# 4   21   8.2             78           82              8            2
#
#    Projects  Attendance  Placed
# 0         5          92       1
# 1         2          80       0
# 2         6          96       1
# 3         1          75       0
# 4         4          90       1

# %%
X=df.drop('Placed',axis=1)
y=df['Placed']

# %%
X
# Out:
#    Age  CGPA  AptitudeScore  CodingScore  Communication  Internships  \
# 0   21   8.5             82           90              8            2
# 1   22   7.1             60           55              6            1
# 2   20   9.0             91           95              9            3
# 3   23   6.8             58           60              5            0
# 4   21   8.2             78           82              8            2
# 5   22   7.5             70           72              7            1
# 6   24   5.9             45           40              4            0
# 7   20   9.3             94           97             10            4
# 8   23   6.5             52           48              5            0
# 9   21   8.0             76           80              7            2
#
#    Projects  Attendance
# 0         5          92
# 1         2          80
# 2         6          96
# 3         1          75
# 4         4          90
# 5         3          85
# 6         0          68
# 7         8          98
# 8         2          70
# 9         4          89

# %%
y
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    1
# 8    0
# 9    1
# Name: Placed, dtype: int64

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
X_test
# Out:
#    Age  CGPA  AptitudeScore  CodingScore  Communication  Internships  \
# 8   23   6.5             52           48              5            0
# 1   22   7.1             60           55              6            1
#
#    Projects  Attendance
# 8         2          70
# 1         2          80

# %%
# Features Scalling
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 1.13389342, -1.31993266, -1.44931151, -1.60554594, -1.21355975,
#         -1.34715063, -0.77459667, -1.71946025],
#        [ 0.37796447, -0.75424723, -0.92821074, -1.21800037, -0.67419986,
#         -0.57735027, -0.77459667, -0.68519844]])

# %%
X_train_scaled
# Out:
# array([[ 0.37796447, -0.37712362, -0.27683478, -0.27681827, -0.13483997,
#         -0.57735027, -0.36147845, -0.16806754],
#        [-0.37796447,  0.56568542,  0.50481637,  0.71972749,  0.40451992,
#          0.19245009,  0.464758  ,  0.55591572],
#        [-1.13389342,  1.31993266,  1.28646752,  1.10727306,  1.4832397 ,
#          1.73205081,  1.70411267,  1.1764728 ],
#        [-1.13389342,  1.03708995,  1.09105473,  0.99654576,  0.94387981,
#          0.96225045,  0.87787623,  0.96962044],
#        [-0.37796447,  0.0942809 ,  0.11399079,  0.16609096, -0.13483997,
#          0.19245009,  0.05163978,  0.24563718],
#        [-0.37796447,  0.28284271,  0.24426598,  0.27681827,  0.40451992,
#          0.19245009,  0.05163978,  0.34906336],
#        [ 1.13389342, -1.03708995, -1.05848593, -0.94118211, -1.21355975,
#         -1.34715063, -1.18771489, -1.20232935],
#        [ 1.88982237, -1.88561808, -1.90527468, -2.04845517, -1.75291964,
#         -1.34715063, -1.60083312, -1.92631261]])

# %%
df
# Out:
#    Age  CGPA  AptitudeScore  CodingScore  Communication  Internships  \
# 0   21   8.5             82           90              8            2
# 1   22   7.1             60           55              6            1
# 2   20   9.0             91           95              9            3
# 3   23   6.8             58           60              5            0
# 4   21   8.2             78           82              8            2
# 5   22   7.5             70           72              7            1
# 6   24   5.9             45           40              4            0
# 7   20   9.3             94           97             10            4
# 8   23   6.5             52           48              5            0
# 9   21   8.0             76           80              7            2
#
#    Projects  Attendance  Placed
# 0         5          92       1
# 1         2          80       0
# 2         6          96       1
# 3         1          75       0
# 4         4          90       1
# 5         3          85       1
# 6         0          68       0
# 7         8          98       1
# 8         2          70       0
# 9         4          89       1

# %%
# Create KNN model
from sklearn.neighbors import KNeighborsClassifier

model=KNeighborsClassifier(
    n_neighbors=5,
    metric='minkowski',
    p=2
)

# %%
# Train Model
model.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Model Prediction

y_pred=model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([1, 1])

# %%
y_test
# Out:
# 8    0
# 1    0
# Name: Placed, dtype: int64

# %%
# Model Evalution
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print('Accuracy')
print(accuracy_score(y_test,y_pred))
# Out:
# Accuracy
# 0.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[0 2]
#  [0 0]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       2.0
#            1       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt
accuracy=[]

for k in range(1,4):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled,y_train)
    pred=knn.predict(X_test_scaled)
    acc=accuracy_score(y_test,pred)
    accuracy.append(acc)
plt.figure(figsize=(10,5))
plt.plot(range(1,4),accuracy,marker='d')
plt.xlabel('K Value')
plt.ylabel("Accuracy")
plt.title('Choosing Best K Value')
plt.grid(True)
plt.show()

# %%
accuracy = []

max_k = len(X_train)

for k in range(1, max_k + 1):

    knn = KNeighborsClassifier(n_neighbors=k)

    knn.fit(X_train_scaled, y_train)

    pred = knn.predict(X_test_scaled)

    acc = accuracy_score(y_test, pred)

    accuracy.append(acc)

plt.figure(figsize=(10,5))
plt.plot(range(1, max_k + 1), accuracy, marker="o")
plt.xlabel("K")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

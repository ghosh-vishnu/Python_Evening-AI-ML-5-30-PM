# %%
# 1.KNN Metrics
> Euclidean Distance
Distance=root(x2​−x1​)2+(y2​−y1​)2
​

# %%
# Student A
height=160
weight=55


# New Student
height1=163
weight1=58

# %%
# height Diff
print(height1-height)
# Out:
# 3

# %%
print(weight1-weight)
# Out:
# 3

# %%
9+9=18
root(18)=4.24

# %%
# STUDENT B
height=162
weight=58
# New Student 
height1=163
weight1=58

# %%
# height diff
163-162=1
58-57=1

# %%
root(2)
1.414

# Student C
height=175
weight=75
# new_student
height1=163
weight1=58

# %%
height_diff=12
weight_diff=17
144+289=433
root(433)=20.80

# %%
Studnet  height  weight   Sports            Result
A        160       55      Football          4.24                           
B        163       58      FOOTBAL           1.41
C        175       75      BASKET BALL       20.80
new      163       58       --------
FOOTBALL

# %%
IF K=1
SPORT=FOOTBALL

# %%
import math

# Student A
x1=160
y1=55

# New Student
X2=163
Y2=58

distance=math.sqrt((X2-x1)**2+(Y2-y1)**2)
print("Distance is ",distance)
# Out:
# Distance is  4.242640687119285

# %%
import numpy as np
point1=np.array([160,55])
point2=np.array([163,58])
distance=np.sum(np.abs(point2-point1))

# %%
print(distance)
# Out:
# 6

# %%
features
AGE                    25
SALARY                 5000000
